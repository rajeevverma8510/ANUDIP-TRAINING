# %% [markdown]
# Calculate the total revenue generated by two product categories in a store
# category1 revenue np.array([500, 600, 700, 5501)
# category2_revenue = np.array([450, 700, 800, 6001)

# %%
import numpy as np
category1_revenue =np.array([500, 600, 700, 550]) 
category2_revenue = np.array([450,700,800,600])
Total_revenue = category1_revenue + category2_revenue
print("Total Revenue",Total_revenue)
# Out:
# Total Revenue [ 950 1300 1500 1150]

# %% [markdown]
# Calculate teh Profit Made by Company
# revenue = np.array([10000,12000,11000,10500])
# expenses = np.array([4000,5000,4500,4800])

# %%
import numpy as np
revenue = np.array([10000,12000,11000,10500])
expenses = np.array([4000,5000,4500,4800])
Profit = revenue - expenses
print("Profit ",Profit)
# Out:
# Profit  [6000 7000 6500 5700]

# %% [markdown]
# Determine which products in a store are out of stock (quantity is 0).
#
# Input: inventory= np.array([10,0, 5, 0, 20,0])

# %%
import numpy as np
inventory= np.array([10,0,5,0,20,0])
print("Out of Stock",inventory[inventory==0])
# Out:
# Out of Stock [0 0 0]

# %% [markdown]
# Calculate the total cost of items in a shopping cart, considering the quantity and price per item.
# Input:
# quantity=np.array([2, 3, 4, 1])
# price_per_item=np.array([10.0, 5.0, 8.0, 12.0])

# %%
import numpy as np
quantity=np.array([2, 3, 4, 1])
price_per_item=np.array([10.0, 5.0,8.0,12.0])
print("Total Cost of Item",quantity*price_per_item)
# Out:
# Total Cost of Item [20. 15. 32. 12.]
